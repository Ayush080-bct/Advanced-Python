# %%
import requests,json
response=requests.get("https://catfact.ninja/facts?limit=3")
data=response.json()
with open ("fa.json","w") as f:
    json.dump(data,f,indent=2)#2 spaces per level

# %%
import pprint #preety print , a bulit in python module
r=requests.get("https://catfact.ninja/breeds?limit=2")
pprint.pprint(r.json())
# Out:
# {'current_page': 1,
#  'data': [{'breed': 'Abyssinian',
#            'coat': 'Short',
#            'country': 'Ethiopia',
#            'origin': 'Natural/Standard',
#            'pattern': 'Ticked'},
#           {'breed': 'Aegean',
#            'coat': 'Semi-long',
#            'country': 'Greece',
#            'origin': 'Natural/Standard',
#            'pattern': 'Bi- or tri-colored'}],
#  'first_page_url': 'https://catfact.ninja/breeds?page=1',
#  'from': 1,
#  'last_page': 49,
#  'last_page_url': 'https://catfact.ninja/breeds?page=49',
#  'links': [{'active': False, 'label': 'Previous', 'url': None},
#            {'active': True,
#             'label': '1',
#             'url': 'https://catfact.ninja/breeds?page=1'},
#            {'active': False,
#             'label': '2',
#             'url': 'https://catfact.ninja/breeds?page=2'},
#            {'active': False,
#             'label': '3',
#             'url': 'https://catfact.ninja/breeds?page=3'},
# ...

# %%
res=requests.post("https://httpbin.org/post",json={"username":"ayush"})
pprint.pprint(res.json())
# Out:
# {'args': {},
#  'data': '{"username": "ayush"}',
#  'files': {},
#  'form': {},
#  'headers': {'Accept': '*/*',
#              'Accept-Encoding': 'gzip, deflate',
#              'Content-Length': '21',
#              'Content-Type': 'application/json',
#              'Host': 'httpbin.org',
#              'User-Agent': 'python-requests/2.32.5',
#              'X-Amzn-Trace-Id': 'Root=1-696e6e42-3b64709e14de4bd42267b091'},
#  'json': {'username': 'ayush'},
#  'origin': '27.34.68.181',
#  'url': 'https://httpbin.org/post'}
